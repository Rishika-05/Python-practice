# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('canada_per_capita_income.csv')

df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
df.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %%
# %matplotlib inline

plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.title('Canada per Capita Income')
plt.scatter(df.year, df['per capita income (US$)'], color = 'blue', marker = '*')

plt.plot(df.year, reg.predict(df[['year']]), color = 'red')  # best fit line

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['year']], df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %% [markdown]
# #### So the per capita income in the year 2020 should be around 41,288.69409442 as predicted by the model.

# %% [markdown]
# #### Extra

# %%
d = pd.read_csv('yearPredict.csv')

d
# Out:
#     year
# 0   2020
# 1   2021
# 2   2022
# 3   2023
# 4   2024
# 5   2025
# 6   2026
# 7   2027
# 8   2028
# 9   2029
# 10  2030

# %%
pci = reg.predict(d)

pci
# Out:
# array([41288.69409442, 42117.15916964, 42945.62424486, 43774.08932009,
#        44602.55439531, 45431.01947053, 46259.48454575, 47087.94962098,
#        47916.4146962 , 48744.87977142, 49573.34484664])

# %%
d['per capita income (US$)'] = pci

d
# Out:
#     year  per capita income (US$)
# 0   2020             41288.694094
# 1   2021             42117.159170
# 2   2022             42945.624245
# 3   2023             43774.089320
# 4   2024             44602.554395
# 5   2025             45431.019471
# 6   2026             46259.484546
# 7   2027             47087.949621
# 8   2028             47916.414696
# 9   2029             48744.879771
# 10  2030             49573.344847

# %%
d.to_csv('prediction.csv', index = False)

# %%
# %matplotlib inline

plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.title('Predicted Canada per Capita Income')
plt.plot(d.year, d['per capita income (US$)'], color = 'blue', marker = '*')
