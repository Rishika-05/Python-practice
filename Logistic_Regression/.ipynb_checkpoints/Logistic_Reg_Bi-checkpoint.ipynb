# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# ### 1. Data Analysis

# %%
ppl_left = df[df['left'] == 1]
ppl_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3571 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     3571 non-null   float64
#  1   last_evaluation        3571 non-null   float64
#  2   number_project         3571 non-null   int64
#  3   average_montly_hours   3571 non-null   int64
#  4   time_spend_company     3571 non-null   int64
#  5   Work_accident          3571 non-null   int64
#  6   left                   3571 non-null   int64
#  7   promotion_last_5years  3571 non-null   int64
#  8   Department             3571 non-null   object
#  9   salary                 3571 non-null   object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 306.9+ KB

# %%
ppl_retained = df[df['left'] == 0]
ppl_retained.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11428 entries, 2000 to 14210
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11428 non-null  float64
#  1   last_evaluation        11428 non-null  float64
#  2   number_project         11428 non-null  int64
#  3   average_montly_hours   11428 non-null  int64
#  4   time_spend_company     11428 non-null  int64
#  5   Work_accident          11428 non-null  int64
#  6   left                   11428 non-null  int64
#  7   promotion_last_5years  11428 non-null  int64
#  8   Department             11428 non-null  object
#  9   salary                 11428 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 982.1+ KB

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# #### Conclusion from the above table -
#          1. Satisfaction Level - Employees with low satisfaction level are more likely to leave the firm.
#          2. Average Month Hours - Monthy hours are high among employees leaving the firm.
#          3. Promotion Last 5 years - Employees getting promoted are likely to stay.

# %% [markdown]
# ### 2. Impact on Employees salaries on retention

# %%
pd.crosstab(df['salary'], df['left']).plot(kind = 'bar', title = 'Impact on employees salaries on retention',
                                           xlabel = 'Salary', ylabel = 'No. of employees', color = ['blue','red'])
# Out:
# <AxesSubplot:title={'center':'Impact on employees salaries on retention'}, xlabel='Salary', ylabel='No. of employees'>

# %% [markdown]
#  Employees with low salary are most likely to leave and employees with high salaries stays

# %% [markdown]
# ### 3. Corelation between department & employee retention

# %%
pd.crosstab(df['Department'], df['left']).plot(kind = 'bar', title = 'Relation b/w department & employees retention',
                                           xlabel = 'Salary', ylabel = 'No. of employees', color = ['blue','red'])
# Out:
# <AxesSubplot:title={'center':'Relation b/w department & employees retention'}, xlabel='Salary', ylabel='No. of employees'>

# %% [markdown]
# The above graph do not provide much impact on the employees retention.

# %% [markdown]
# ### 4. The variables we'll use to build logistic regression model are :
#         1. Satisfaction Level
#         2. Average Month Hours
#         3. Promotion Last 5 years
#         4. Salary

# %%
new_df = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]

new_df
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %% [markdown]
# #### As the salaries coloums are string we will modify out df to make use of salary.

# %%
sal_dummies = pd.get_dummies(new_df.salary, prefix = "salary")

# %%
new_df = pd.concat([new_df, sal_dummies], axis='columns')
new_df.drop('salary',axis = 'columns',inplace = True)

new_df
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
X = new_df

X
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
y = df.left

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.4)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# ### 5. Measuring the accuracy of model

# %%
model.score(X_test,y_test)
# Out:
# 0.7843333333333333

# %% [markdown]
# #### So accuracy of the model is around 77.97%
